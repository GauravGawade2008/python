# %%
import pandas as pd

# %%
# reading csv file 
df = pd.read_csv("student_marks.csv")

# %%
# understanding the data statistics.
print("Information: ")
df.info()
print(df.describe())
print(f"\nTotal no. of null values: \n{df.isnull().sum()}")
# Out:
# Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   student_id    15 non-null     int64
#  1   name          15 non-null     str
#  2   age           14 non-null     float64
#  3   math          13 non-null     float64
#  4   science       13 non-null     float64
#  5   english       14 non-null     float64
#  6   attendance_%  14 non-null     float64
#  7   grade         15 non-null     str
# dtypes: float64(5), int64(1), str(2)
# memory usage: 1.1 KB
#        student_id        age       math    science    english  attendance_%
# count   15.000000  14.000000  13.000000  13.000000  14.000000     14.000000
# mean   107.066667  17.785714  76.461538  78.538462  74.142857     78.357143
# std      4.366539   0.801784  14.734401  14.569462  14.426776     20.322807
# min    101.000000  17.000000  48.000000  52.000000  44.000000     40.000000
# 25%    103.500000  17.000000  66.000000  70.000000  68.250000     62.500000
# 50%    107.000000  18.000000  79.000000  82.000000  76.500000     87.500000
# 75%    110.500000  18.000000  88.000000  90.000000  84.000000     92.000000
# max    114.000000  19.000000  95.000000  97.000000  93.000000     99.000000
#
# Total no. of null values:
# student_id      0
# name            0
# age             1
# math            2
# science         2
# english         1
# attendance_%    1
# grade           0
# dtype: int64

# %%
# removes duplicate column 
df = df.drop_duplicates()

# %%
# name column is cleaned with title case and proper spacing.
df["name"] = df["name"].str.strip().str.title().str.replace(r'\s+', ' ', regex=True)

# %%
# filling missing values 
numeric_cols = ["attendance_%","math","science","english"]
df[numeric_cols] = df[numeric_cols].fillna(value = df[numeric_cols].mean().round(2))

# %%
df["age"] = df["age"].fillna(value = df["age"].median()).astype(int)

# %%
#finding out the  students with attendance below 60% and filter them out 
print("\nStudents with attendance below 60% :")
print(df[df["attendance_%"] < 60 ].filter(items= ["name", "attendance_%"]))
df = df[df["attendance_%"] >= 60]
# Out:
# Students with attendance below 60% :
#            name  attendance_%
# 6   Karan Singh          45.0
# 8    Amit Verma          55.0
# 11    Ravi Teja          40.0

# %%
# finding out the average marks and adding the column
df["average_marks"] = (( df["math"] + df["science"] + df["english"]) / 3).round(2)

# %%
# displaying the top 5 rankers and class average
print(f"Top 5 of the class: \n{df.nlargest(5,'average_marks')[['name','average_marks']]}")
print(f"Class average: {df['average_marks'].mean().round(2)}")
# Out:
# Top 5 of the class:
#             name  average_marks
# 9    Pooja Gupta          95.00
# 3    Sneha Joshi          92.67
# 14  Lakshmi Iyer          87.67
# 0   Aarav Sharma          84.33
# 5     Divya Nair          81.28
# Class average: 79.43

# %%
# cleaned data
print(f"Final cleaned data: \n{df}")
# Out:
# Final cleaned data:
#     student_id          name  age   math  science  english  attendance_%  \
# 0          101  Aarav Sharma   17  85.00    90.00    78.00         92.00
# 1          102   Priya Patel   18  75.75    76.00    88.00         85.00
# 2          103   Rohit Kumar   17  72.00    77.58    65.00         70.00
# 3          104   Sneha Joshi   19  91.00    95.00    92.00         98.00
# 4          105   Arjun Mehta   18  55.00    60.00    50.00         60.00
# 5          106    Divya Nair   17  88.00    82.00    73.85         88.00
# 7          108   Meera Reddy   19  77.00    80.00    75.00         91.00
# 9          110   Pooja Gupta   18  95.00    97.00    93.00         99.00
# 12         112    Ananya Das   17  79.00    83.00    81.00         87.00
# 13         113   Vikas Yadav   18  66.00    70.00    68.00         77.31
# 14         114  Lakshmi Iyer   19  90.00    88.00    85.00         95.00
#
#    grade  average_marks
# 0      A          84.33
# 1      B          79.92
# 2      C          71.53
# 3      A          92.67
# 4      D          55.00
# 5      B          81.28
# 7      B          77.33
# 9      A          95.00
# 12     B          81.00
# 13     C          68.00
# 14     A          87.67

# %%
# saving the cleaned csv into new csv file
df.to_csv("cleaned_student_marks.csv", index= False)
