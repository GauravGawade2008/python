# %%
import pandas as pd

# %%
# reading csv file 
df = pd.read_csv("sales_transactions.csv")

# %%
# display data
pd.set_option("display.max_columns", None)
print(df.head())
# Out:
#    order_id        date     product     category  quantity  unit_price region  \
# 0      1001  2024-01-05      Laptop  Electronics         2       55000  North
# 1      1002  2024-01-12       Phone  Electronics         5       22000  South
# 2      1003  2024-02-03      Tablet  Electronics         3       18000   East
# 3      1004  2024-02-18      Laptop  Electronics         1       55000   West
# 4      1005  2024-03-07  Headphones  Accessories        10        2500  North
#
#   salesperson  total_amount
# 0        Ravi        110000
# 1       Priya        110000
# 2       Arjun         54000
# 3       Sneha         55000
# 4        Ravi         25000

# %%
# understanding the data statistics.
print("\nInformation: ")
df.info()
print(df.describe())
print(f"\nTotal no. of null values: \n{df.isnull().sum()}")
# Out:
# Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      20 non-null     int64
#  1   date          20 non-null     str
#  2   product       20 non-null     str
#  3   category      20 non-null     str
#  4   quantity      20 non-null     int64
#  5   unit_price    20 non-null     int64
#  6   region        20 non-null     str
#  7   salesperson   20 non-null     str
#  8   total_amount  20 non-null     int64
# dtypes: int64(4), str(5)
# memory usage: 1.5 KB
#          order_id   quantity    unit_price  total_amount
# count    20.00000  20.000000     20.000000      20.00000
# mean   1010.50000   6.950000  20395.000000   63375.00000
# std       5.91608   6.629083  19387.393489   47449.38439
# min    1001.00000   1.000000    800.000000   12000.00000
# 25%    1005.75000   2.000000   2500.000000   23625.00000
# 50%    1010.50000   4.500000  18000.000000   54500.00000
# 75%    1015.25000   9.250000  22000.000000  108500.00000
# max    1020.00000  25.000000  55000.000000  176000.00000
#
# Total no. of null values:
# order_id        0
# date            0
# product         0
# category        0
# quantity        0
# unit_price      0
# region          0
# salesperson     0
# total_amount    0
# dtype: int64

# %%
# checking the exact column names
print("column names: ")
print(df.columns.to_list())
# Out:
# column names:
# ['order_id', 'date', 'product', 'category', 'quantity', 'unit_price', 'region', 'salesperson', 'total_amount']

# %%
# converting date column to datetime
df["date"] = pd.to_datetime(df["date"])

# %%
# inserting quater and month column
df.insert(1, "quarter", df["date"].dt.quarter)
df.insert(2, "month", df["date"].dt.month)

# %%
# total Revenue by Category
print("\nRevenue by category: ")
print(df.groupby("category")["total_amount"].sum())
# Out:
# Revenue by category:
# category
# Accessories     125500
# Electronics    1142000
# Name: total_amount, dtype: int64

# %%
# total revenue per product
print("\nTotal revenue per product: ")
print(df.groupby("product")["total_amount"].sum().sort_values(ascending=False))
# Out:
# Total revenue per product:
# product
# Phone         506000
# Laptop        330000
# Tablet        234000
# Headphones     77500
# Monitor        72000
# Keyboard       48000
# Name: total_amount, dtype: int64

# %%
# total quantity sold per region
print("\nTotal quantity sold per region: ")
print(df.groupby("region")["quantity"].sum())
# Out:
# Total quantity sold per region:
# region
# East     26
# North    36
# South    31
# West     46
# Name: quantity, dtype: int64

# %%
# top sales person by total revenue
print("\nTop sales person by total revenue: ")
print(df.groupby("salesperson")["total_amount"].sum().sort_values(ascending=False))
# Out:
# Top sales person by total revenue:
# salesperson
# Arjun    348500
# Sneha    323000
# Ravi     315000
# Priya    281000
# Name: total_amount, dtype: int64

# %%
# Top Salesperson by Quantity
print("\nTop sales person by total quantity: ")
print(df.groupby("salesperson")["quantity"].sum().sort_values(ascending=False))
# Out:
# Top sales person by total quantity:
# salesperson
# Sneha    46
# Ravi     36
# Priya    31
# Arjun    26
# Name: quantity, dtype: int64

# %%
# Average Order Value
print(f"Average order value: {df["total_amount"].mean()}")
# Out:
# Average order value: 63375.0

# %%
# Monthly Revenue Trend
print(f"Monthly revenue trend: ")
print(df.groupby("month")["total_amount"].sum())
# Out:
# Monthly revenue trend:
# month
# 1     220000
# 2     109000
# 3     113000
# 4     132000
# 5      67000
# 6     206000
# 7      52000
# 8     182000
# 9     144000
# 10     22500
# 11     20000
# Name: total_amount, dtype: int64

# %%
# best selling month using groupby on month
print("\nbest selling month: ")
print(df.groupby("month")["total_amount"].sum().sort_values(ascending=False))
# Out:
# best selling month:
# month
# 1     220000
# 6     206000
# 8     182000
# 9     144000
# 4     132000
# 3     113000
# 2     109000
# 5      67000
# 7      52000
# 10     22500
# 11     20000
# Name: total_amount, dtype: int64

# %%
# Filter only Electronics category and find its % of total revenue
total_revenue = df["total_amount"].sum()
electronics_revenue = df.loc[df["category"] == "Electronics","total_amount"].sum()
electronics_revenue_percent = ( electronics_revenue / total_revenue ) * 100
print(f"\nFilter only Electronics category and find its % of total revenue: {electronics_revenue_percent.round(2)}")
# Out:
# Filter only Electronics category and find its % of total revenue: 90.1
